# %% [markdown]
# # 🇵🇰 Pakistani Politician Image Classifier - COMPLETE PIPELINE
#
# ## 📋 Instructions:
# 1. Upload BOTH files to Kaggle:
#    - This notebook (`RUN_THIS_ON_KAGGLE.ipynb`)
#    - The script (`kaggle_training_complete.py`)
# 2. Enable GPU (Settings → Accelerator → GPU)
# 3. Run all cells below
# 4. Wait 4-6 hours
# 5. Download `/kaggle/working/` folders
#
# ## ⏱️ Estimated Time: 4-6 hours with GPU
#
# ## 📦 Output:
# - `/kaggle/working/models/` - Trained models
# - `/kaggle/working/plots/` - Training curves & confusion matrices
# - `/kaggle/working/results/` - Evaluation reports

# %%
# Run the complete training pipeline
# !python kaggle_training_complete.py

# %% [markdown]
# ## ✅ Done!
#
# If you see "TRAINING PIPELINE COMPLETE!" above, download these folders:
# 1. `/kaggle/working/models/`
# 2. `/kaggle/working/plots/`
# 3. `/kaggle/working/results/`
